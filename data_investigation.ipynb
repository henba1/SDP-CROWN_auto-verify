# %%
from sdp_data_viewer import load_sdp_data, view_sdp_data

# %%
# Load data
X, y = load_sdp_data("./datasets/sdp", "cifar")

# %%
# View data
view_sdp_data("./datasets/sdp", "cifar")
# Out:
# ...
# SDP Dataset: CIFAR
# ...
#
# Features (X_sdp.npy):
#   Shape: (200, 32, 32, 3)
#   Dtype: float32
#   Min: 0.000000, Max: 1.000000, Mean: 0.470237, Std: 0.252574
#
# Labels (y_sdp.npy):
#   Shape: (200,)
#   Dtype: int64
#   Min: 0, Max: 9
#   Unique labels: 10
#   Label distribution: {0: 29, 1: 20, 2: 20, 3: 17, 4: 18, 5: 24, 6: 27, 7: 15, 8: 16, 9: 14}
#
# Dataset Summary:
#   Number of samples: 200
#   Feature dimensions: (32, 32, 3)
#   Samples match labels: ✓
#
# Sample 0:
#   Features shape: (32, 32, 3)
#   Label: 3
#   Feature range: [0.000000, 0.968628]
#   Feature mean: 0.069974
